# %%
import numpy as np
import pandas as pd
import tensorflow as tf

x=np.array([1,2,3,4],dtype=float)
y=np.array([2,4,6,8],dtype=float)

# Define model using Input layer (Recommended)
model=tf.keras.Sequential([
    tf.keras.Input(shape=(1,)), # preferred over input_shape in Dense
    tf.keras.layers.Dense(1)
])

# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# Train the model
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 74.8792
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 52.0036
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 36.1304
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 25.1161
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 17.4732
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 12.1697
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 8.4894
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 5.9355
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 4.1631
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 2.9330

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Convert lists to numPy arrays
x=np.array([1,2,3,4],dtype=float)
y=np.array([2,4,6,8],dtype=float)

# Define the model
model=Sequential([
    Dense(1,input_shape=(1,))
])

# Compile the model
model.compile(optimizer='sgd',loss='mse')

# Train the model
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 9.6802
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 6.7229
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 4.6708
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.2469
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.2589
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.5733
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.0975
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.7673
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.5382
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.3792

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Define a Simple Linear Model
model=nn.Linear(1,1)

# Loss and Optimizer
criterion=nn.MSELoss()
optimizer=optim.SGD(model.parameters(),lr=0.01)

# Dummy Data
x=torch.tensor([[1.],[2.],[3.],[4.]])
y=torch.tensor([[2.],[4.],[6.],[8.]])

# Training loop
for epoch in range(10):
  optimizer.zero_grad()
  output=model(x)
  loss=criterion(output,y)
  loss.backward()
  optimizer.step()
  print(f"Epoch {epoch+1}, Loss {loss.item()}")
# Out:
# Epoch 1, Loss 60.53168487548828
# Epoch 2, Loss 42.03501892089844
# Epoch 3, Loss 29.200366973876953
# Epoch 4, Loss 20.294475555419922
# Epoch 5, Loss 14.11467170715332
# Epoch 6, Loss 9.826440811157227
# Epoch 7, Loss 6.850730895996094
# Epoch 8, Loss 4.7857561111450195
# Epoch 9, Loss 3.35272216796875
# Epoch 10, Loss 2.3581788539886475

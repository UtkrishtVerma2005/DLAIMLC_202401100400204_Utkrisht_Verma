# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

vocab_size = 10000
max_len = 200

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size)

x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)

model = Sequential([
    Embedding(vocab_size, 128, input_length=max_len),
    LSTM(128),
    Dropout(0.5),
    Dense(1, activation="sigmoid")
])

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()

history = model.fit(
    x_train,
    y_train,
    epochs=3,
    batch_size=64,
    validation_split=0.2
)

loss, accuracy = model.evaluate(x_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 171s 537ms/step - accuracy: 0.7825 - loss: 0.4509 - val_accuracy: 0.8398 - val_loss: 0.3523
# Epoch 2/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 165s 526ms/step - accuracy: 0.8963 - loss: 0.2698 - val_accuracy: 0.8642 - val_loss: 0.3506
# Epoch 3/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 161s 515ms/step - accuracy: 0.9257 - loss: 0.1990 - val_accuracy: 0.8722 - val_loss: 0.3292
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 97ms/step - accuracy: 0.8646 - loss: 0.3484
# Test Accuracy: 0.8646399974822998

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("LSTM Text Classification Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("LSTM Text Classification Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense

input_texts = [
    "one", "two", "three", "four", "five",
    "six", "seven", "eight", "nine", "ten"
]

target_texts = [
    "\tone\n", "\tdo\n", "\tteen\n", "\tchaar\n", "\tpaanch\n",
    "\tchhe\n", "\tsaat\n", "\taath\n", "\tnau\n", "\tdas\n"
]

input_chars = sorted(list(set("".join(input_texts))))
target_chars = sorted(list(set("".join(target_texts))))

num_encoder_tokens = len(input_chars)
num_decoder_tokens = len(target_chars)

max_encoder_seq_length = max(len(txt) for txt in input_texts)
max_decoder_seq_length = max(len(txt) for txt in target_texts)

input_token_index = dict([(char, i) for i, char in enumerate(input_chars)])
target_token_index = dict([(char, i) for i, char in enumerate(target_chars)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype="float32"
)

decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32"
)

decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32"
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0

    for t, char in enumerate(target_text):
        decoder_input_data[i, t, target_token_index[char]] = 1.0

        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0

latent_dim = 256

encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

encoder_states = [state_h, state_c]

decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(
    latent_dim,
    return_sequences=True,
    return_state=True
)

decoder_outputs, _, _ = decoder_lstm(
    decoder_inputs,
    initial_state=encoder_states
)

decoder_dense = Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=2,
    epochs=300,
    validation_split=0.2
)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, None, 14)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_2       │ (None, None, 14)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 256),     │    277,504 │ input_layer_1[0]… │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, None,     │    277,504 │ input_layer_2[0]… │
# │                     │ 256), (None,      │            │ lstm_1[0][1],     │
# │                     │ 256), (None,      │            │ lstm_1[0][2]      │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, None, 14)  │      3,598 │ lstm_2[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 558,606 (2.13 MB)
#  Trainable params: 558,606 (2.13 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - accuracy: 0.0625 - loss: 1.6474 - val_accuracy: 0.0000e+00 - val_loss: 1.3066
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2344 - loss: 1.6078 - val_accuracy: 0.1250 - val_loss: 1.2882
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2188 - loss: 1.5593 - val_accuracy: 0.1250 - val_loss: 1.2521
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.1875 - loss: 1.4755 - val_accuracy: 0.1250 - val_loss: 1.1802
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.1875 - loss: 1.3566 - val_accuracy: 0.2500 - val_loss: 1.1654
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.2188 - loss: 1.3161 - val_accuracy: 0.2500 - val_loss: 1.2348
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.2344 - loss: 1.3492 - val_accuracy: 0.2500 - val_loss: 1.3121
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.2031 - loss: 1.3566 - val_accuracy: 0.2500 - val_loss: 1.3468
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.2031 - loss: 1.3119 - val_accuracy: 0.2500 - val_loss: 1.3897
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.2188 - loss: 1.2688 - val_accuracy: 0.1250 - val_loss: 1.4232
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2344 - loss: 1.2089 - val_accuracy: 0.2500 - val_loss: 1.3898
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2344 - loss: 1.1536 - val_accuracy: 0.2500 - val_loss: 1.3799
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2344 - loss: 1.1226 - val_accuracy: 0.2500 - val_loss: 1.3723
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2656 - loss: 1.0816 - val_accuracy: 0.2500 - val_loss: 1.3778
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2812 - loss: 1.0359 - val_accuracy: 0.1875 - val_loss: 1.3661
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2812 - loss: 0.9914 - val_accuracy: 0.1875 - val_loss: 1.3888
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2969 - loss: 0.9291 - val_accuracy: 0.1875 - val_loss: 1.4159
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.2969 - loss: 0.8714 - val_accuracy: 0.1875 - val_loss: 1.4252
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3750 - loss: 0.8473 - val_accuracy: 0.1875 - val_loss: 1.4463
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4219 - loss: 0.7970 - val_accuracy: 0.1875 - val_loss: 1.4516
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4219 - loss: 0.7579 - val_accuracy: 0.1250 - val_loss: 1.4361
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4375 - loss: 0.7566 - val_accuracy: 0.1250 - val_loss: 1.4428
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4531 - loss: 0.6795 - val_accuracy: 0.1875 - val_loss: 1.4231
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4375 - loss: 0.6442 - val_accuracy: 0.1875 - val_loss: 1.4428
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4688 - loss: 0.6161 - val_accuracy: 0.1875 - val_loss: 1.4601
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - loss: 0.5765 - val_accuracy: 0.1875 - val_loss: 1.4722
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4844 - loss: 0.5364 - val_accuracy: 0.1875 - val_loss: 1.4767
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5312 - loss: 0.5312 - val_accuracy: 0.1875 - val_loss: 1.4381
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4844 - loss: 0.5339 - val_accuracy: 0.1875 - val_loss: 1.4621
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5156 - loss: 0.4922 - val_accuracy: 0.1250 - val_loss: 1.5582
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5312 - loss: 0.4967 - val_accuracy: 0.1875 - val_loss: 1.5269
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5000 - loss: 0.4816 - val_accuracy: 0.1875 - val_loss: 1.4344
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5469 - loss: 0.4639 - val_accuracy: 0.1250 - val_loss: 1.4683
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4844 - loss: 0.5281 - val_accuracy: 0.0625 - val_loss: 1.6646
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5000 - loss: 0.4640 - val_accuracy: 0.1250 - val_loss: 1.6434
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5469 - loss: 0.4459 - val_accuracy: 0.1875 - val_loss: 1.4616
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5625 - loss: 0.4428 - val_accuracy: 0.1875 - val_loss: 1.5160
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5938 - loss: 0.3928 - val_accuracy: 0.1250 - val_loss: 1.6934
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5938 - loss: 0.3702 - val_accuracy: 0.1875 - val_loss: 1.6225
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5781 - loss: 0.3605 - val_accuracy: 0.1875 - val_loss: 1.6211
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5938 - loss: 0.3521 - val_accuracy: 0.1875 - val_loss: 1.6478
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6094 - loss: 0.3402 - val_accuracy: 0.1250 - val_loss: 1.6857
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6094 - loss: 0.3439 - val_accuracy: 0.1250 - val_loss: 1.6692
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.3296 - val_accuracy: 0.1250 - val_loss: 1.6451
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5938 - loss: 0.3210 - val_accuracy: 0.1875 - val_loss: 1.6498
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6094 - loss: 0.3268 - val_accuracy: 0.1875 - val_loss: 1.7033
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6094 - loss: 0.3366 - val_accuracy: 0.1250 - val_loss: 1.7158
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6094 - loss: 0.3237 - val_accuracy: 0.1250 - val_loss: 1.6878
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.3266 - val_accuracy: 0.1875 - val_loss: 1.6385
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6094 - loss: 0.3083 - val_accuracy: 0.1875 - val_loss: 1.6733
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6094 - loss: 0.2983 - val_accuracy: 0.1250 - val_loss: 1.7298
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6094 - loss: 0.3116 - val_accuracy: 0.1875 - val_loss: 1.6765
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6094 - loss: 0.3067 - val_accuracy: 0.1875 - val_loss: 1.6721
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6094 - loss: 0.2930 - val_accuracy: 0.1875 - val_loss: 1.7053
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6250 - loss: 0.2906 - val_accuracy: 0.1875 - val_loss: 1.7195
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6094 - loss: 0.2797 - val_accuracy: 0.1875 - val_loss: 1.7264
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2926 - val_accuracy: 0.1875 - val_loss: 1.7425
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6250 - loss: 0.2780 - val_accuracy: 0.1875 - val_loss: 1.7248
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.6250 - loss: 0.2745 - val_accuracy: 0.1875 - val_loss: 1.7389
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.6250 - loss: 0.2652 - val_accuracy: 0.1875 - val_loss: 1.7518
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6250 - loss: 0.2629 - val_accuracy: 0.1875 - val_loss: 1.7053
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6250 - loss: 0.2795 - val_accuracy: 0.1875 - val_loss: 1.7543
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6250 - loss: 0.2597 - val_accuracy: 0.1875 - val_loss: 1.7728
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2699 - val_accuracy: 0.1875 - val_loss: 1.7230
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2632 - val_accuracy: 0.1250 - val_loss: 1.8226
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6250 - loss: 0.2662 - val_accuracy: 0.1875 - val_loss: 1.6101
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5938 - loss: 0.3273 - val_accuracy: 0.1250 - val_loss: 1.8337
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5781 - loss: 0.2602 - val_accuracy: 0.1250 - val_loss: 1.7440
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6094 - loss: 0.2918 - val_accuracy: 0.1875 - val_loss: 1.5404
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5938 - loss: 0.3124 - val_accuracy: 0.1875 - val_loss: 1.6594
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6094 - loss: 0.2947 - val_accuracy: 0.1875 - val_loss: 1.7508
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5938 - loss: 0.3095 - val_accuracy: 0.1875 - val_loss: 1.7629
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6094 - loss: 0.2612 - val_accuracy: 0.1875 - val_loss: 1.7449
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6094 - loss: 0.2732 - val_accuracy: 0.1875 - val_loss: 1.6498
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2869 - val_accuracy: 0.1875 - val_loss: 1.7290
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2580 - val_accuracy: 0.1250 - val_loss: 1.7930
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2455 - val_accuracy: 0.1875 - val_loss: 1.7215
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6250 - loss: 0.2635 - val_accuracy: 0.1875 - val_loss: 1.6988
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2519 - val_accuracy: 0.1250 - val_loss: 1.7918
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6094 - loss: 0.2360 - val_accuracy: 0.1875 - val_loss: 1.7404
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2576 - val_accuracy: 0.1875 - val_loss: 1.6779
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2571 - val_accuracy: 0.1250 - val_loss: 1.8044
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2349 - val_accuracy: 0.1875 - val_loss: 1.7694
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2469 - val_accuracy: 0.1875 - val_loss: 1.7202
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2506 - val_accuracy: 0.1875 - val_loss: 1.7515
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2341 - val_accuracy: 0.1875 - val_loss: 1.7569
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2360 - val_accuracy: 0.1875 - val_loss: 1.7209
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2417 - val_accuracy: 0.1875 - val_loss: 1.7623
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2326 - val_accuracy: 0.1875 - val_loss: 1.7854
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2344 - val_accuracy: 0.1875 - val_loss: 1.7345
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2398 - val_accuracy: 0.1875 - val_loss: 1.7395
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2307 - val_accuracy: 0.1875 - val_loss: 1.7611
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2280 - val_accuracy: 0.1875 - val_loss: 1.7485
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2347 - val_accuracy: 0.1875 - val_loss: 1.7606
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6250 - loss: 0.2301 - val_accuracy: 0.1875 - val_loss: 1.7643
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2345 - val_accuracy: 0.1875 - val_loss: 1.7490
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2312 - val_accuracy: 0.1875 - val_loss: 1.7538
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2235 - val_accuracy: 0.1875 - val_loss: 1.7581
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2283 - val_accuracy: 0.1875 - val_loss: 1.7400
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2306 - val_accuracy: 0.1875 - val_loss: 1.7589
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2258 - val_accuracy: 0.1250 - val_loss: 1.8103
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2277 - val_accuracy: 0.1875 - val_loss: 1.7538
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2310 - val_accuracy: 0.1875 - val_loss: 1.7425
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2263 - val_accuracy: 0.1875 - val_loss: 1.7615
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2304 - val_accuracy: 0.1875 - val_loss: 1.7647
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 0.2276 - val_accuracy: 0.1875 - val_loss: 1.7639
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2269 - val_accuracy: 0.1875 - val_loss: 1.7564
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6250 - loss: 0.2278 - val_accuracy: 0.1875 - val_loss: 1.7612
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6250 - loss: 0.2246 - val_accuracy: 0.1875 - val_loss: 1.7678
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6250 - loss: 0.2281 - val_accuracy: 0.1875 - val_loss: 1.7653
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6250 - loss: 0.2290 - val_accuracy: 0.1875 - val_loss: 1.7698
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6250 - loss: 0.2270 - val_accuracy: 0.1875 - val_loss: 1.7597
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6250 - loss: 0.2278 - val_accuracy: 0.1875 - val_loss: 1.7617
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.6250 - loss: 0.2304 - val_accuracy: 0.1875 - val_loss: 1.7791
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6250 - loss: 0.2341 - val_accuracy: 0.1875 - val_loss: 1.7706
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6250 - loss: 0.2394 - val_accuracy: 0.1875 - val_loss: 1.7641
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2326 - val_accuracy: 0.1875 - val_loss: 1.7677
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2272 - val_accuracy: 0.1875 - val_loss: 1.7624
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2388 - val_accuracy: 0.1875 - val_loss: 1.7901
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - loss: 0.2350 - val_accuracy: 0.1875 - val_loss: 1.7789
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6250 - loss: 0.2449 - val_accuracy: 0.1875 - val_loss: 1.7596
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2348 - val_accuracy: 0.1875 - val_loss: 1.7906
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6250 - loss: 0.2273 - val_accuracy: 0.1875 - val_loss: 1.7593
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2392 - val_accuracy: 0.1875 - val_loss: 1.7747
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2319 - val_accuracy: 0.1875 - val_loss: 1.8021
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2375 - val_accuracy: 0.1875 - val_loss: 1.7615
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2399 - val_accuracy: 0.1875 - val_loss: 1.7936
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6250 - loss: 0.2258 - val_accuracy: 0.1875 - val_loss: 1.7855
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2435 - val_accuracy: 0.1875 - val_loss: 1.7601
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2359 - val_accuracy: 0.1875 - val_loss: 1.8100
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2306 - val_accuracy: 0.1250 - val_loss: 1.8283
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6250 - loss: 0.2428 - val_accuracy: 0.1875 - val_loss: 1.7441
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6250 - loss: 0.2353 - val_accuracy: 0.1875 - val_loss: 1.7799
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2264 - val_accuracy: 0.1875 - val_loss: 1.8027
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2441 - val_accuracy: 0.1875 - val_loss: 1.7769
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6250 - loss: 0.2339 - val_accuracy: 0.1875 - val_loss: 1.7912
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6250 - loss: 0.2334 - val_accuracy: 0.1875 - val_loss: 1.7650
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2374 - val_accuracy: 0.1875 - val_loss: 1.7901
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2257 - val_accuracy: 0.1875 - val_loss: 1.7806
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6250 - loss: 0.2339 - val_accuracy: 0.1875 - val_loss: 1.7552
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2403 - val_accuracy: 0.1875 - val_loss: 1.8078
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2261 - val_accuracy: 0.1875 - val_loss: 1.7885
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2301 - val_accuracy: 0.1875 - val_loss: 1.7171
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2528 - val_accuracy: 0.1250 - val_loss: 1.8986
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6250 - loss: 0.2348 - val_accuracy: 0.1875 - val_loss: 1.8014
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2452 - val_accuracy: 0.1875 - val_loss: 1.7169
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2413 - val_accuracy: 0.1250 - val_loss: 1.8815
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2320 - val_accuracy: 0.1250 - val_loss: 1.8396
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2370 - val_accuracy: 0.1875 - val_loss: 1.7321
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6250 - loss: 0.2378 - val_accuracy: 0.1875 - val_loss: 1.7384
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2326 - val_accuracy: 0.1875 - val_loss: 1.7920
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2239 - val_accuracy: 0.1875 - val_loss: 1.7792
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2327 - val_accuracy: 0.1875 - val_loss: 1.7472
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2344 - val_accuracy: 0.1875 - val_loss: 1.7657
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6250 - loss: 0.2294 - val_accuracy: 0.1875 - val_loss: 1.7708
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2342 - val_accuracy: 0.1875 - val_loss: 1.7662
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2322 - val_accuracy: 0.1875 - val_loss: 1.7626
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2251 - val_accuracy: 0.1875 - val_loss: 1.7556
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6250 - loss: 0.2291 - val_accuracy: 0.1875 - val_loss: 1.7635
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6250 - loss: 0.2300 - val_accuracy: 0.1875 - val_loss: 1.7863
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.6250 - loss: 0.2274 - val_accuracy: 0.1875 - val_loss: 1.7822
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6250 - loss: 0.2307 - val_accuracy: 0.1875 - val_loss: 1.7562
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6250 - loss: 0.2295 - val_accuracy: 0.1875 - val_loss: 1.7644
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.6250 - loss: 0.2243 - val_accuracy: 0.1875 - val_loss: 1.7735
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6250 - loss: 0.2271 - val_accuracy: 0.1875 - val_loss: 1.7729
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2308 - val_accuracy: 0.1875 - val_loss: 1.7740
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6250 - loss: 0.2274 - val_accuracy: 0.1875 - val_loss: 1.7730
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6250 - loss: 0.2266 - val_accuracy: 0.1875 - val_loss: 1.7654
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2327 - val_accuracy: 0.1875 - val_loss: 1.7661
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6250 - loss: 0.2259 - val_accuracy: 0.1875 - val_loss: 1.7723
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - loss: 0.2242 - val_accuracy: 0.1875 - val_loss: 1.7613
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2334 - val_accuracy: 0.1875 - val_loss: 1.7802
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2246 - val_accuracy: 0.1875 - val_loss: 1.7680
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2233 - val_accuracy: 0.1875 - val_loss: 1.7588
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2255 - val_accuracy: 0.1875 - val_loss: 1.7676
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2253 - val_accuracy: 0.1875 - val_loss: 1.7920
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - loss: 0.2252 - val_accuracy: 0.1875 - val_loss: 1.7681
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2282 - val_accuracy: 0.1875 - val_loss: 1.7528
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2283 - val_accuracy: 0.1875 - val_loss: 1.7723
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6250 - loss: 0.2256 - val_accuracy: 0.1875 - val_loss: 1.7837
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2244 - val_accuracy: 0.1875 - val_loss: 1.7593
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2243 - val_accuracy: 0.1875 - val_loss: 1.7654
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2231 - val_accuracy: 0.1875 - val_loss: 1.7834
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2249 - val_accuracy: 0.1875 - val_loss: 1.7665
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2290 - val_accuracy: 0.1875 - val_loss: 1.7699
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2245 - val_accuracy: 0.1875 - val_loss: 1.7716
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2232 - val_accuracy: 0.1875 - val_loss: 1.7665
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2238 - val_accuracy: 0.1875 - val_loss: 1.7626
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2259 - val_accuracy: 0.1875 - val_loss: 1.7687
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2260 - val_accuracy: 0.1875 - val_loss: 1.7739
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2237 - val_accuracy: 0.1875 - val_loss: 1.7684
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2223 - val_accuracy: 0.1875 - val_loss: 1.7639
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - loss: 0.2214 - val_accuracy: 0.1875 - val_loss: 1.7684
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2242 - val_accuracy: 0.1875 - val_loss: 1.7677
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2270 - val_accuracy: 0.1875 - val_loss: 1.7723
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6250 - loss: 0.2232 - val_accuracy: 0.1875 - val_loss: 1.7709
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2225 - val_accuracy: 0.1875 - val_loss: 1.7576
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6250 - loss: 0.2222 - val_accuracy: 0.1875 - val_loss: 1.7650
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2196 - val_accuracy: 0.1875 - val_loss: 1.7677
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6250 - loss: 0.2263 - val_accuracy: 0.1875 - val_loss: 1.7703
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2266 - val_accuracy: 0.1875 - val_loss: 1.7712
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6250 - loss: 0.2256 - val_accuracy: 0.1875 - val_loss: 1.7672
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2210 - val_accuracy: 0.1875 - val_loss: 1.7646
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2204 - val_accuracy: 0.1875 - val_loss: 1.7564
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6250 - loss: 0.2264 - val_accuracy: 0.1875 - val_loss: 1.7760
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6250 - loss: 0.2210 - val_accuracy: 0.1875 - val_loss: 1.7672
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2224 - val_accuracy: 0.1875 - val_loss: 1.7508
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2239 - val_accuracy: 0.1875 - val_loss: 1.7749
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6250 - loss: 0.2206 - val_accuracy: 0.1875 - val_loss: 1.7736
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6250 - loss: 0.2228 - val_accuracy: 0.1875 - val_loss: 1.7609
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.6250 - loss: 0.2217 - val_accuracy: 0.1875 - val_loss: 1.7809
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6250 - loss: 0.2182 - val_accuracy: 0.1875 - val_loss: 1.7512
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.6250 - loss: 0.2316 - val_accuracy: 0.1875 - val_loss: 1.7756
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6250 - loss: 0.2212 - val_accuracy: 0.1875 - val_loss: 1.7776
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2207 - val_accuracy: 0.1875 - val_loss: 1.7508
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2250 - val_accuracy: 0.1875 - val_loss: 1.7863
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6250 - loss: 0.2193 - val_accuracy: 0.1875 - val_loss: 1.7645
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - loss: 0.2266 - val_accuracy: 0.1875 - val_loss: 1.7794
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6250 - loss: 0.2195 - val_accuracy: 0.1875 - val_loss: 1.7858
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - loss: 0.2184 - val_accuracy: 0.1875 - val_loss: 1.7509
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6250 - loss: 0.2246 - val_accuracy: 0.1875 - val_loss: 1.7868
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2216 - val_accuracy: 0.1875 - val_loss: 1.7873
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2246 - val_accuracy: 0.1875 - val_loss: 1.7213
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2231 - val_accuracy: 0.1250 - val_loss: 1.8460
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6250 - loss: 0.2154 - val_accuracy: 0.1875 - val_loss: 1.8256
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2347 - val_accuracy: 0.1875 - val_loss: 1.7377
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2246 - val_accuracy: 0.1250 - val_loss: 1.8604
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - loss: 0.2177 - val_accuracy: 0.1875 - val_loss: 1.8216
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6250 - loss: 0.2254 - val_accuracy: 0.1875 - val_loss: 1.7448
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - loss: 0.2184 - val_accuracy: 0.1875 - val_loss: 1.8073
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - loss: 0.2207 - val_accuracy: 0.1875 - val_loss: 1.7989
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6250 - loss: 0.2295 - val_accuracy: 0.1875 - val_loss: 1.7769
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6094 - loss: 0.2226 - val_accuracy: 0.1875 - val_loss: 1.7737
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2274 - val_accuracy: 0.1875 - val_loss: 1.7582
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6094 - loss: 0.2461 - val_accuracy: 0.1875 - val_loss: 1.7825
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2211 - val_accuracy: 0.1875 - val_loss: 1.7851
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5938 - loss: 0.2264 - val_accuracy: 0.1875 - val_loss: 1.7538
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6250 - loss: 0.2377 - val_accuracy: 0.1875 - val_loss: 1.8378
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5938 - loss: 0.2438 - val_accuracy: 0.1875 - val_loss: 1.8099
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6094 - loss: 0.2452 - val_accuracy: 0.1875 - val_loss: 1.7952
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2280 - val_accuracy: 0.1875 - val_loss: 1.8703
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2248 - val_accuracy: 0.1875 - val_loss: 1.8225
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2254 - val_accuracy: 0.1875 - val_loss: 1.7772
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2253 - val_accuracy: 0.1875 - val_loss: 1.7785
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - loss: 0.2217 - val_accuracy: 0.1875 - val_loss: 1.8039
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2223 - val_accuracy: 0.1875 - val_loss: 1.8171
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6250 - loss: 0.2254 - val_accuracy: 0.1875 - val_loss: 1.8050
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2229 - val_accuracy: 0.1875 - val_loss: 1.8108
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2197 - val_accuracy: 0.1875 - val_loss: 1.8042
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6250 - loss: 0.2237 - val_accuracy: 0.1875 - val_loss: 1.7968
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6250 - loss: 0.2219 - val_accuracy: 0.1875 - val_loss: 1.8090
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2175 - val_accuracy: 0.1875 - val_loss: 1.8056
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2162 - val_accuracy: 0.1875 - val_loss: 1.8148
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2181 - val_accuracy: 0.1875 - val_loss: 1.8083
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2208 - val_accuracy: 0.1875 - val_loss: 1.8002
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2220 - val_accuracy: 0.1875 - val_loss: 1.8081
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6250 - loss: 0.2224 - val_accuracy: 0.1875 - val_loss: 1.7920
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6250 - loss: 0.2242 - val_accuracy: 0.1875 - val_loss: 1.7915
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.6250 - loss: 0.2202 - val_accuracy: 0.1875 - val_loss: 1.8032
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.6250 - loss: 0.2167 - val_accuracy: 0.1875 - val_loss: 1.7953
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.6250 - loss: 0.2171 - val_accuracy: 0.1875 - val_loss: 1.7847
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6250 - loss: 0.2198 - val_accuracy: 0.1875 - val_loss: 1.7903
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6250 - loss: 0.2181 - val_accuracy: 0.1875 - val_loss: 1.8035
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6250 - loss: 0.2181 - val_accuracy: 0.1875 - val_loss: 1.7973
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2213 - val_accuracy: 0.1875 - val_loss: 1.7895
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2202 - val_accuracy: 0.1875 - val_loss: 1.7916
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2172 - val_accuracy: 0.1875 - val_loss: 1.8023
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6250 - loss: 0.2184 - val_accuracy: 0.1875 - val_loss: 1.7939
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6250 - loss: 0.2196 - val_accuracy: 0.1875 - val_loss: 1.7764
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6250 - loss: 0.2188 - val_accuracy: 0.1875 - val_loss: 1.7896
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2193 - val_accuracy: 0.1875 - val_loss: 1.7962
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2209 - val_accuracy: 0.1875 - val_loss: 1.7817
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6250 - loss: 0.2192 - val_accuracy: 0.1875 - val_loss: 1.7849
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - loss: 0.2179 - val_accuracy: 0.1875 - val_loss: 1.7855
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6250 - loss: 0.2202 - val_accuracy: 0.1875 - val_loss: 1.7785
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2179 - val_accuracy: 0.1875 - val_loss: 1.7847
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6250 - loss: 0.2159 - val_accuracy: 0.1875 - val_loss: 1.7861
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2157 - val_accuracy: 0.1875 - val_loss: 1.7791
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6250 - loss: 0.2175 - val_accuracy: 0.1875 - val_loss: 1.7850
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2200 - val_accuracy: 0.1875 - val_loss: 1.7913
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2220 - val_accuracy: 0.1875 - val_loss: 1.7782
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - loss: 0.2206 - val_accuracy: 0.1875 - val_loss: 1.7807
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2160 - val_accuracy: 0.1875 - val_loss: 1.7804
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - loss: 0.2154 - val_accuracy: 0.1875 - val_loss: 1.7758
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6250 - loss: 0.2175 - val_accuracy: 0.1875 - val_loss: 1.7840
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2209 - val_accuracy: 0.1875 - val_loss: 1.7815
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6250 - loss: 0.2202 - val_accuracy: 0.1875 - val_loss: 1.7765
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6250 - loss: 0.2161 - val_accuracy: 0.1875 - val_loss: 1.7814
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2144 - val_accuracy: 0.1875 - val_loss: 1.7734
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2171 - val_accuracy: 0.1875 - val_loss: 1.7736
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2182 - val_accuracy: 0.1875 - val_loss: 1.7823
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6250 - loss: 0.2170 - val_accuracy: 0.1875 - val_loss: 1.7840
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - loss: 0.2185 - val_accuracy: 0.1875 - val_loss: 1.7777
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6250 - loss: 0.2175 - val_accuracy: 0.1875 - val_loss: 1.7716
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6250 - loss: 0.2147 - val_accuracy: 0.1875 - val_loss: 1.7764
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6250 - loss: 0.2144 - val_accuracy: 0.1875 - val_loss: 1.7830
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2147 - val_accuracy: 0.1875 - val_loss: 1.7880
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6250 - loss: 0.2151 - val_accuracy: 0.1875 - val_loss: 1.7681
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6250 - loss: 0.2150 - val_accuracy: 0.1875 - val_loss: 1.7733
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6250 - loss: 0.2113 - val_accuracy: 0.1875 - val_loss: 1.7779

# %%
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs,
    initial_state=decoder_states_inputs
)

decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states
)

reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())

def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)

    target_seq = np.zeros((1, 1, num_decoder_tokens))
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    decoded_sentence = ""

    while True:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value
        )

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]

        decoded_sentence += sampled_char

        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            break

        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        states_value = [h, c]

    return decoded_sentence

for seq_index in range(10):
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)

    print("Input:", input_texts[seq_index])
    print("Predicted Output:", decoded_sentence)
    print()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Input: one
# Predicted Output: one
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Input: two
# Predicted Output: do
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Input: three
# Predicted Output: teen
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Input: four
# Predicted Output: chaar
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Input: five
# Predicted Output: paanch
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Input: six
# Predicted Output: chhe
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Input: seven
# Predicted Output: saat
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Input: eight
# Predicted Output: aath
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Input: nine
# Predicted Output: aat
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Input: ten
# Predicted Output: tee
